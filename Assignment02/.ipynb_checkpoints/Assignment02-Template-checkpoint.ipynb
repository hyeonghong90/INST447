# %% [markdown]
# # Assignment 02: Web Scraping
# Your Name: Hyeong-gi Hong
# Your Class: INST 447
# Your Section: TTh 0102

# %%
import requests
from bs4 import BeautifulSoup
import sqlite3
import time

# %% [markdown]
# ## Are Amazon reviews fake?
# Should we trust Amazon reviews?
#
# That is a question that seems like we could answer if we only had enough data. So, lets collect some data. Your assignment is to scrape the reviews for five (5) similar products and to save those reviews into a sqllite database, that I have provided. The database will store:
#
# **Product Table:**
# product_id - int - Primary key (this auto-increments).
# amazon_identifier - text - The identifier for the product.
# product_name - text - The name of the product.
# product_price - text - The price of the product. (Text because sometimes it is a range)
# scraper_name - text - Your name...
#
# **Review Table:**
# review_id - int - Primary key (this auto-increments).
# review_date - text - The date of the review.
# review_title - text - The title of the review.
# number_of_stars - int - The number of stars the review gave.
# verified_purchase - bool - Was the it a "Verifed Purchase"?
# review_body - text - The text of the review.
# number_found_helpful - int - The number of people that found the review helpful.
# product_id - int - Foreign key for the product.
#
# Since you are using my database structure, this means that I can run your code and fill up a single database with all of our data.
#
# ** YOU DO NOT HAVE TO DO ANYTHING WITH amazon-page_dump.db IF YOU ARE GETTING RESPONSES FROM AMAZON **
# I have also given you a database named 'amazon-page_dump.db'. If you keep getting errors from Amazon, then tell me what that error is including the status-code, the reason given, and what you think that error means. Then use the pages saved in the page_dump table to complete the assignment. You will have to figure out how to best adapt the code framework I gave you to pull out the pages to parse.
#
# **Database: amazon-page_dump.db
# Table: page_dump**
# dump_id - integer - Primary key (this auto-increments)
# amazon_identifier - text - The Amazon product identifier
# page_url - text - The url for the page
# page_html - text - The html of the page
#
# This is only in case you are getting only errors from Amazon and cannot access the pages to scrape. ** YOU DO NOT HAVE TO DO ANYTHING WITH amazon-page_dump.db IF YOU ARE GETTING RESPONSES FROM AMAZON **

# %%
# Create the amazon.db database, if it does not exist.
conn = sqlite3.connect('amazon.db')
c = conn.cursor()

# %%
# Create the products table 
c.execute('''
    CREATE TABLE IF NOT EXISTS products (
        product_id INTEGER PRIMARY KEY AUTOINCREMENT,
        amazon_identifier TEXT,
        product_name TEXT,
        product_price TEXT,
        scraper_name TEXT
        );
''')
# Create the reviews table
c.execute('''
    CREATE TABLE IF NOT EXISTS reviews (
        review_id INTEGER PRIMARY KEY AUTOINCREMENT,
        review_date TEXT, 
        review_title TEXT, 
        number_of_stars INTEGER, 
        verified_purchase BOOLEAN, 
        review_body TEXT, 
        number_found_helpful INTEGER,
        product_id INTEGER,
        FOREIGN KEY(product_id) REFERENCES products(product_id)
        )
''')

# %% [markdown]
# ## Your Task
#
# Find 5 similar products on Amazon that have more than 5 reviews each (my example uses hotsauce, so you can't). Your products must be PG.
# Grab their product identifiers and replace mine in the list I have below.
#
# It is in the URL and it looks like these:

# %%
product_lists = ['B013WC0P2A', 'B001DHECXA', 'B075B4KRJT', 'B075M3YY18', 'B0072NZ292']

# %% [markdown]
# And the Urls for the reviews look like: https://www.amazon.com/product-reviews/B00AIR3Q38/?reviewerType=all_reviews&pageNumber=1
#
# Notice that there is a spot in the url where the Amazon identifier goes and that there is an argument to be able to set the number of the page that is accesed.

# %%
# URL template
url = 'https://www.amazon.com/product-reviews/%s/'
# Default URL arguments
url_args = {'reviewerType': 'all_reviews',
            'pageNumber': 1,
            'sortBy': 'recent'}
# Pretend to be a browser
headers = {'user-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:59.0) Gecko/20100101 Firefox/59.0'}

# %% [markdown]
# Now loop through the identifiers and save the specified data into the database.
#
# I have provided a shell. Fill out the bits that have comments that are like:
# >#TASK: Get (x) data

# %%
# Loop through the Amazon product identifiers
for amazon_identifier in product_lists:
    # Get the first page
    url_args['pageNumber'] = 1
    r = requests.get(url % amazon_identifier, url_args)
    print(r.url)
    
    # Check if the request was successful.
    if r.status_code == requests.codes.ok:
        page_soup = BeautifulSoup(r.content, 'lxml')
        
        # TASK: Get the number of the last page and save it into the variable max_page number
        # note: make sure you handle the cases where there is a last button and when there isn't a last button
        pages = page_soup.find_all('li', attrs={'class': 'page-button'})
        max_page_number = 1
        
        if len(pages) != 0:
            for page in pages:
                n_page = page.text.replace(',', '');
                if max_page_number < int(n_page):
                    max_page_number = int(n_page)
        
        # TASK: Get the product name and save to the variable below
        product_name = page_soup.find('div', attrs={'class': 'a-row product-title'}).text
        
        # TASK: Get the product price and save to the variable below
        product_price = page_soup.find('span', attrs={'class': 'a-color-price arp-price'}).text
        
        # TASK: Change this to your name
        scraper_name = 'Hyeong-gi Hong'
        
        # Try to insert it. If this does not work, then we won't have a product_id to associate the reviews with and shouldn't save them.
        try:
            c.execute('INSERT INTO products (amazon_identifier, product_name, product_price, scraper_name) VALUES (?, ?, ?, ?)', 
                      (amazon_identifier, product_name, product_price, scraper_name))
            # We have to commit the transaction, or it won't be saved.
            conn.commit()
            # Save the last primary key inserted as the product_id
            product_id = c.lastrowid

            # If there are more than 5 pages, then stop at 5. 
            if max_page_number > 5:
                max_page_number = 5
            
            # Loop through all of the pages (1 through max)
            for page in range(1, max_page_number): 
                # Set the page number for the url
                url_args['pageNumber'] = page
                # Get the next page of reviews
                r = requests.get(url % amazon_identifier, url_args)
                print(r.url)
                # Check if we got a response
                if r.status_code == requests.codes.ok:
                    review_soup = BeautifulSoup(r.content, 'lxml')
                    review_pages = review_soup.find_all('div', attrs={'class': 'a-section review'})
                    
                    month_num = {'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6,
                                 'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12}
                    
                    # TASK: Loop through the reviews (replace the [] with your code)
                    for review in review_pages:
                        
                        # TASK: Get the review date - convert it if necessary to YYYY-MM-DD
                        date_div = review.find('span', attrs={'class':'a-size-base a-color-secondary review-date'})
                        date = date_div.text.split(' ')
                        year = date[3]
                        month = date[1]
                        for m in month_num:
                            if month == m:
                                month = month_num[m]
                        day = date[2].strip(',')

                        review_date = "{}-{:02d}-{:02d}".format(year, month, int(day))

                        # TASK: Get the review title
                        review_title = review.find('a', attrs={'class': 'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text
                        
                        # TASK: Get the number of stars - and make sure it is an int.
                        number_of_stars = int(review.find('a', attrs={'class': 'a-link-normal'}).text[0])
                        
                        # TASK: Get whether it is a verified purchase or not
                        verified_purchase = False
                        if review.find('span', attrs={'class': 'a-size-mini a-color-state a-text-boldd'}) == None:
                            verified_purchase = True
                            
                        # TASK: Get the actual text of the review
                        review_body = review.find('div', attrs={'class': 'a-row review-data'}).text
                        
                        # TASK: Get the number of people that found the review helpful
                        number_found_helpful = 0
                        review_votes = review.find('span', attrs={'class': 'review-votes'})
                        if review_votes != None:
                            num = review_votes.text.replace('\n', '').strip().split(' ')[0]
                            if num == 'One':
                                number_found_helpful = 1
                            else:
                                number_found_helpful = int(num)
                        
                        # Try to insert the review into the database. If it doesn't work. Then tell us why.
                        try:
                            c.execute('''INSERT INTO reviews 
                                            (product_id, review_date, review_title, number_of_stars, verified_purchase, review_body, number_found_helpful) 
                                         VALUES (?, ?, ?, ?, ?, ?, ?)''', 
                                      (product_id, review_date, review_title, number_of_stars, verified_purchase, review_body, number_found_helpful))
                            conn.commit()    
                        except sqlite3.DatabaseError as err:
                            print('SQL Error: {0}'.format(err))
                else: 
                    print('Error %s for %s on page %s' % (r.status_code, amazon_identifier, page))
                    
                # Slow things down.
                time.sleep(0.5)
        except sqlite3.DatabaseError as err:
            print('SQL Error: {0}'.format(err))
    else:
        print('Error %s for %s' % (r.status_code, amazon_identifier))
#     # Slow things down.
    time.sleep(0.5)
# Out:
# https://www.amazon.com/product-reviews/B013WC0P2A/?reviewerType=all_reviews&pageNumber=1&sortBy=recent
# https://www.amazon.com/product-reviews/B013WC0P2A/?reviewerType=all_reviews&pageNumber=1&sortBy=recent
# https://www.amazon.com/product-reviews/B013WC0P2A/?reviewerType=all_reviews&pageNumber=2&sortBy=recent
# https://www.amazon.com/product-reviews/B013WC0P2A/?reviewerType=all_reviews&pageNumber=3&sortBy=recent
# https://www.amazon.com/product-reviews/B013WC0P2A/?reviewerType=all_reviews&pageNumber=4&sortBy=recent
# https://www.amazon.com/product-reviews/B001DHECXA/?reviewerType=all_reviews&pageNumber=1&sortBy=recent
# https://www.amazon.com/product-reviews/B001DHECXA/?reviewerType=all_reviews&pageNumber=1&sortBy=recent
# https://www.amazon.com/product-reviews/B001DHECXA/?reviewerType=all_reviews&pageNumber=2&sortBy=recent
# https://www.amazon.com/product-reviews/B001DHECXA/?reviewerType=all_reviews&pageNumber=3&sortBy=recent
# https://www.amazon.com/product-reviews/B001DHECXA/?reviewerType=all_reviews&pageNumber=4&sortBy=recent
# Error 503 for B001DHECXA on page 4
# https://www.amazon.com/product-reviews/B075B4KRJT/?reviewerType=all_reviews&pageNumber=1&sortBy=recent
# https://www.amazon.com/product-reviews/B075M3YY18/?reviewerType=all_reviews&pageNumber=1&sortBy=recent
# https://www.amazon.com/product-reviews/B075M3YY18/?reviewerType=all_reviews&pageNumber=1&sortBy=recent
# https://www.amazon.com/product-reviews/B075M3YY18/?reviewerType=all_reviews&pageNumber=2&sortBy=recent
# https://www.amazon.com/product-reviews/B075M3YY18/?reviewerType=all_reviews&pageNumber=3&sortBy=recent
# https://www.amazon.com/product-reviews/B075M3YY18/?reviewerType=all_reviews&pageNumber=4&sortBy=recent
# https://www.amazon.com/product-reviews/B0072NZ292/?reviewerType=all_reviews&pageNumber=1&sortBy=recent
# https://www.amazon.com/product-reviews/B0072NZ292/?reviewerType=all_reviews&pageNumber=1&sortBy=recent
# https://www.amazon.com/product-reviews/B0072NZ292/?reviewerType=all_reviews&pageNumber=2&sortBy=recent
# https://www.amazon.com/product-reviews/B0072NZ292/?reviewerType=all_reviews&pageNumber=3&sortBy=recent
# https://www.amazon.com/product-reviews/B0072NZ292/?reviewerType=all_reviews&pageNumber=4&sortBy=recent

# %% [markdown]
# Checking to see if there are products

# %%
c.execute('SELECT COUNT(*) FROM products;')
c.fetchone()
# Out:
# (5,)

# %%
c.execute('SELECT * FROM products;')
c.fetchall()
# Out:
# [(1,
#   'B013WC0P2A',
#   'VicTsing MM057 2.4G Wireless Portable Mobile Mouse Optical Mice with USB Receiver, 5 Adjustable DPI Levels, 6 Buttons for Notebook, PC, Laptop, Computer, Macbook - Black',
#   '$9.99',
#   'Hyeong-gi Hong'),
#  (2,
#   'B001DHECXA',
#   'TeckNet Classic 2.4G Portable Optical Wireless Mouse with USB Nano Receiver for Notebook,PC,Laptop,Computer,6 Buttons,30 Months Battery Life,4800 DPI,6 Adjustment Levels',
#   '$12.49',
#   'Hyeong-gi Hong'),
#  (3,
#   'B075B4KRJT',
#   'Bluetooth Mouse, DINOWIN 3.0 Portable Mouse with Rechargeable Wireless USB Mouse Silent for Bluetooth-compatible Laptop,Mac,iMac,Macbook Android Tablet,PC Adjustable DPI 1000/1400/1600 (Black)',
#   '$19.99',
#   'Hyeong-gi Hong'),
#  (4,
#   'B075M3YY18',
#   'VicTsing Wireless Gaming Mouse with Unique Silent Click, Breathing Backlit, 6 Programmable Buttons, 2400 DPI, Ergonomic Grips, 7 Buttons- Black',
#   '$19.99',
#   'Hyeong-gi Hong'),
#  (5,
#   'B0072NZ292',
#   'HP A0X35AA#ABA Wireless Mouse X4000 with Laser Sensor',
#   '$18.99',
#   'Hyeong-gi Hong')]

# %% [markdown]
# Checking to see if there are reviews

# %%
c.execute('SELECT COUNT(*) FROM reviews;')
c.fetchone()
# Out:
# (150,)

# %%
c.execute('SELECT * FROM reviews;')
c.fetchall()
# Out:
# [(1,
#   '2018-04-12',
#   'Great mouse',
#   5,
#   1,
#   'Works great. Easy installation',
#   0,
#   1),
#  (2,
#   '2018-04-12',
#   'Loved it till it broke 6 months later... buying another one :)',
#   5,
#   1,
#   'bought it last October. Love everything about it! Very comfy, the back and forward buttons right about the thumb, adjustable cpi etc. but today it stopped working. dont know, mid game (tf2 haha) lost connection, changed batteries and nothing. figured it was a faulty one or due to my 2 little kids constantly dropping it. oh well at 10 bucks lets buy another one. and it will be here later tonight!',
#   0,
#   1),
#  (3,
#   '2018-04-12',
#   'Scroll Wheel is completely defunct.',
#   1,
#   1,
#   'I’d give 0 out of 10 if I could. Scroll wheel would jump a little initially but now it’s hit the point where scrolling doesn’t work at all and there were no solutions to how to fix it. Don’t waste your money, the constant headache isnt worth it.It either scrolls and stops and then wont scroll in that specific window (Chrome or otherwise) or it jumps so erratically that you’re better off scrolling in reverse to get where you want to go. And only fix for the no scrolling is to close out the application or window and try again.If you scroll down 2 lines it would scroll down once and then scroll you up 3-4 lines.Initially it would only do it once in a while, usually small enough you might not even notice it, but over time it happens more and more often and the jumps become more erratic and drastic till its completely unusable.Product still looks new and clean has no signs of wear to warrant the scroll not functioning.I have otherwise tried every possible solution; reinstalling the mouse, the drivers, alt mouse settings, wheel scroll settings, plugging the mouse in a different port you name it outside of opening the mouse entirely I’ve tried it to get a fix. Nothings worked and the problem just gets worse.DO NOT BUY.',
#   0,
#   1),
#  (4, '2018-04-12', 'Five Stars', 5, 1, 'It works great.', 0, 1),
#  (5,
#   '2018-04-12',
#   'Good product!',
#   5,
#   1,
#   'So far so good! Great mouse for the price!',
#   0,
#   1),
#  (6,
#   '2018-04-12',
#   'good price, but pretty mediocre',
#   3,
#   1,
#   "the weight distribution feels awkward to me, and the sensor is a little weird. when you lift the mouse to move it back across the mousepad, it will still pick up the movement so it's frustrating to use sometimes.it's just ok. good price though I guess.",
#   0,
#   1),
#  (7, '2018-04-12', 'Five Stars', 5, 1, 'Works great.', 0, 1),
#  (8,
#   '2018-04-12',
#   'Works Perfect',
#   5,
#   1,
#   'Works great, a little smaller than my wired mouse but as to be expected. No on/off switch which is nice since I would most likely forget to turn it off, just falls "asleep" if not used for a few min.',
#   0,
#   1),
#  (9, '2018-04-11', 'Five Stars', 5, 1, 'Great mouse working perfectly', 0, 1),
#  (10,
#   '2018-04-11',
#   'Love this mouse!',
#   5,
#   1,
#   'Very easy set up and is comfortable in my hand! Works great!',
#   0,
#   1),
#  (11,
#   '2018-04-11',
#   'Five Stars',
#   5,
#   1,
#   'Love this mouse. It sleeps when not in use, cute. Speedy delivery too. Thank you so much',
#   0,
#   1),
#  (12,
#   '2018-04-11',
#   'Pleasantly surprised',
#   5,
#   1,
#   "For the money, I'm thrilled. Good range, good battery life, it fits well in the hand and feels solid.",
#   0,
#   1),
#  (13,
#   '2018-04-11',
#   'Comfortable feel.',
#   5,
#   1,
#   'Worked perfectly out of the box.  Comfortable feel.',
#   0,
#   1),
#  (14,
#   '2018-04-11',
#   "It's not a bluetooth mouse",
#   3,
#   1,
#   'For whatever reason this mouse came up when I searched for bluetooth mouse flagged as "Amazon\'s Choice". It\'s not bluetooth compatible - it uses its own proprietary usb adapter. Of course I didn\'t know that until it arrived.That said - its just as good as a Logitech for 4-10x the price so I\'m happy with it for my desktop PC, but my new laptop doesn\'t have any usb 2/3 connectors :(.',
#   0,
#   1),
#  (15,
#   '2018-04-11',
#   'annoying.. so I bought the Logitech silent',
#   3,
#   1,
#   'very loud click... annoying.. so I bought the Logitech silent mouse',
#   0,
#   1),
#  (16, '2018-04-11', 'Five Stars', 5, 1, 'Good mouse', 0, 1),
#  (17,
#   '2018-04-11',
#   'Very disappointed!',
#   1,
#   1,
#   'Laggy. Very disappointed!',
#   0,
#   1),
#  (18, '2018-04-11', 'Five Stars', 5, 1, 'Works great', 0, 1),
#  (19,
#   '2018-04-11',
#   "Solid. Side buttons not programmable ( I don't think)",
#   4,
#   1,
#   'It does what it should. One thing- the two side buttons say "default is forward, back", but I don\'t see any means of setting them to anything else.',
#   0,
#   1),
#  (20,
#   '2018-04-11',
#   "It feels much more comfortable than my old Logitech mouse and has it's sensitivity ...",
#   5,
#   1,
#   "I was pleasantly surprised with the quality of this mouse for the price I paid for it. It feels much more comfortable than my old Logitech mouse and has it's sensitivity feature is a nice addition. Overall good stuff.",
#   0,
#   1),
#  (21,
#   '2018-04-11',
#   'This mouse is totally perfect for daily use',
#   5,
#   1,
#   'This mouse is totally perfect for daily use! As a college student, I was looking for an inexpensive mouse and I came across this one! Thought of giving it a try and I must say it’s great! Glad I got it!',
#   0,
#   1),
#  (22,
#   '2018-04-11',
#   'Great mouse for travel and on-the-go',
#   4,
#   1,
#   "This is a great product for the price. There are never connection issues, works perfectly and smoothly, and the DPI ranges are really great. I would not use this as a home set up mouse tho. I felt it most useful for a on-the-go mouse especially in classrooms, meetings, and travel. I don't think it is large enough to get a good grasp especially when at home. I know that VicTsing makes a larger wireless version of this mouse and I would buy that one next.",
#   0,
#   1),
#  (23,
#   '2018-04-11',
#   'I like the look and feel of this mouse in my ...',
#   5,
#   1,
#   'I like the look and feel of this mouse in my hand. It is very sleek and doesn’t have an unnecessary amount of buttons. I really love this mouse.',
#   0,
#   1),
#  (24,
#   '2018-04-11',
#   'Four Stars',
#   4,
#   1,
#   'Easy to set up and works great!',
#   0,
#   1),
#  (25,
#   '2018-04-11',
#   'Sleepy but good for the price.',
#   4,
#   1,
#   'The mouse works fine but goes to sleep a little too quickly for my taste and it also seems to have a little more drag than most.',
#   0,
#   1),
#  (26, '2018-04-11', 'Five Stars', 5, 1, 'good product', 0, 1),
#  (27,
#   '2018-04-11',
#   'Amazing customer Service!',
#   5,
#   1,
#   'This mouse works awesome!!!! Thank you for replacing the one I had issues with very quickly.',
#   0,
#   1),
#  (28,
#   '2018-04-11',
#   'Five Stars',
#   5,
#   1,
#   'I love this mouse. It is very comfortable, came quickly and is great to use.',
#   0,
#   1),
#  (29,
#   '2018-04-11',
#   'Five Stars',
#   5,
#   1,
#   "It's a great mouse. I recommend",
#   0,
#   1),
#  (30,
#   '2018-04-10',
#   'Scroll-wheel not responding correctly',
#   1,
#   1,
#   'The mouse was expected to run under normal conditions but it has prematurely given out. I have changed the battery and it is still showing signs of failure with the scroll wheel. The left mouse button is also showing failure to respond. Will not recommend this to anyone.',
#   0,
#   1),
#  (31,
#   '2018-04-10',
#   'Great feel, size',
#   5,
#   1,
#   'Great feel, size, and functionality.  No problems with the wireless either.  Main button has a very audible click, maybe a bit too loud, but not annoying or anything.  This is really a great mouse, especially for the price.',
#   0,
#   1),
#  (32,
#   '2018-04-10',
#   'Bought this mouse a year ago, and it JUST ...',
#   2,
#   1,
#   'Bought this mouse a year ago, and it JUST died. I put in a new battery, and nothing. no response.',
#   0,
#   1),
#  (33, '2018-04-10', 'Five Stars', 5, 1, 'Work just fine', 0, 1),
#  (34, '2018-04-10', 'Great buy', 5, 1, 'Great product, low price.', 0, 1),
#  (35,
#   '2018-04-10',
#   'Five Stars',
#   5,
#   1,
#   '1 year and 4 months in still working perfectly on my gaming laptop ^^',
#   0,
#   1),
#  (36,
#   '2018-04-10',
#   'Five Stars',
#   5,
#   1,
#   'Awesome product. Great price. Get one',
#   0,
#   1),
#  (37, '2018-04-10', 'Five Stars', 5, 1, 'love it', 0, 1),
#  (38,
#   '2018-04-10',
#   'Looks like this piece is faulty',
#   1,
#   1,
#   "Looks like this piece is faulty.. it stopped working after 5min use.. no more red light glowing only clicks works but it doesnt show the pointer and doesn't move as well.. Tried changing new battery resetting but no luck.. :(",
#   0,
#   1),
#  (39,
#   '2018-04-10',
#   'The value and the functionality. Its great',
#   5,
#   1,
#   'I got this because it looked cool and was cheap amd it seemed to be better than a regular mouse. I game lightly (AoE, Pokemon TCGO, Skyrim, etc) and this mouse is veristile and consitent and i enjoy the 5 different cpi setting this mouse is truly superb for the price. amazing value!',
#   0,
#   1),
#  (40,
#   '2018-04-10',
#   'Four Stars',
#   4,
#   1,
#   'Shuts off by itself. Need more details about individual controls',
#   0,
#   1),
#  (41,
#   '2018-04-11',
#   'The kids are happy!',
#   5,
#   1,
#   "Nice mouse, got it for my grandchildren's computer. They had trouble with the touchpad on their laptop. They like it so far.",
#   0,
#   2),
#  (42,
#   '2018-04-11',
#   'Super easily to assemble and great for work',
#   5,
#   1,
#   'It was exactly what I wanted! Super easily to assemble and great for work!',
#   0,
#   2),
#  (43, '2018-04-11', 'Five Stars', 5, 1, 'Great Mouse', 0, 2),
#  (44, '2018-04-11', 'Five Stars', 5, 1, 'Great mouse.  Easy to use', 0, 2),
#  (45,
#   '2018-04-11',
#   'Love it! Extra large to fit my hand',
#   5,
#   1,
#   "Love it!  Extra large to fit my hand, it doesn't even need a pad to rest on, it works on any surface!",
#   0,
#   2),
#  (46, '2018-04-11', 'One Star', 1, 1, 'i got used one ~~', 0, 2),
#  (47,
#   '2018-04-11',
#   'Have had for 3 months, it quit working. ...',
#   1,
#   1,
#   'Have had for 3 months, it quit working. The optic light is out. what ever happened to quality! Back to Microsoft!',
#   0,
#   2),
#  (48,
#   '2018-04-10',
#   'Mediocre at best',
#   2,
#   1,
#   'Not a good mouse. Connectivity is OK but not accurate or consistent.',
#   0,
#   2),
#  (49,
#   '2018-04-10',
#   'Five Stars',
#   5,
#   1,
#   'Great deal! It works perfectly! I like it.',
#   0,
#   2),
#  (50, '2018-04-10', '!', 4, 1, 'My 9 yr. old loves it!', 0, 2),
#  (51,
#   '2018-04-10',
#   'Comfortable fit with hand',
#   5,
#   1,
#   'Love the mouse.',
#   0,
#   2),
#  (52,
#   '2018-04-10',
#   'Four Stars',
#   4,
#   1,
#   'nice, simple, and easy on the hand.',
#   0,
#   2),
#  (53,
#   '2018-04-10',
#   'Great product',
#   5,
#   1,
#   'Great price and works well.',
#   0,
#   2),
#  (54,
#   '2018-04-10',
#   'good basic wireless mouse',
#   5,
#   1,
#   'Working great, like that it puts itself to sleep, click it to wake it up.',
#   0,
#   2),
#  (55,
#   '2018-04-10',
#   'Excellent performance. Bought it for the long battery life',
#   5,
#   1,
#   'Truly plug and play in Windows 10. Excellent performance. Bought it for the long battery life. We will see.',
#   0,
#   2),
#  (56,
#   '2018-04-10',
#   'I highly do NOT recommend this product',
#   1,
#   1,
#   'I had this mouse for less than 3 months and it has decided to start spazzing out and moves the cursor all over my screen whenever I do not even touch the mouse. I highly do NOT recommend this product.',
#   0,
#   2),
#  (57,
#   '2018-04-10',
#   'This is a good mouse. However',
#   3,
#   1,
#   'This is a good mouse. However, you will need to click it once following every 50 to 60 seconds of rest to make it fully responsive.',
#   0,
#   2),
#  (58,
#   '2018-04-09',
#   'Five Stars',
#   5,
#   1,
#   'Great product! No issuea with installing!',
#   0,
#   2),
#  (59,
#   '2018-04-09',
#   'Great value.',
#   5,
#   1,
#   'Exactly as described.  Great value.',
#   0,
#   2),
#  (60,
#   '2018-04-09',
#   'Perfect fit for my hand',
#   5,
#   1,
#   'Not too big and not too small. Perfect fit for my hand. USB receiver only lasts about a year. Would buy again.',
#   0,
#   2),
#  (61,
#   '2018-04-09',
#   'Works perfect',
#   5,
#   1,
#   'User is Jim said it is fantastic.',
#   0,
#   2),
#  (62,
#   '2018-04-09',
#   'One Star',
#   1,
#   1,
#   'Package didn’t include USB wireless plug',
#   0,
#   2),
#  (63,
#   '2018-04-09',
#   'Item never worked and was ineligible for return.',
#   1,
#   1,
#   'Item did not work right out of the box. For some reason it is not eligible for return. Do not buy.',
#   0,
#   2),
#  (64,
#   '2018-04-09',
#   'The mouse is great.',
#   5,
#   1,
#   'Best mouse for the price.  Does exactly what I expected and I have no complaints.',
#   0,
#   2),
#  (65, '2018-04-08', 'Five Stars', 5, 1, 'Works great', 0, 2),
#  (66,
#   '2018-04-08',
#   'It has survived our toddler lol',
#   5,
#   1,
#   "Our toddler has football thrown this bad boy across the tile floor I don't even know how many times and it's survived! It has fast response time and is small and convenient for travel. You won't be disappointed with this reasonable purchase!",
#   0,
#   2),
#  (67,
#   '2018-04-08',
#   'Wireless is the best.',
#   5,
#   1,
#   'I am still using it.',
#   0,
#   2),
#  (68,
#   '2018-04-08',
#   'Five Stars',
#   5,
#   1,
#   'Best combination of performance and price.',
#   0,
#   2),
#  (69, '2018-04-08', 'Five Stars', 5, 1, 'It works perfectly.', 0, 2),
#  (70,
#   '2018-04-08',
#   'Very satisfied!!',
#   5,
#   1,
#   'For the money...its a gr8 product! Very satisfied!!',
#   0,
#   2),
#  (71,
#   '2018-04-12',
#   'Not very high quality',
#   2,
#   1,
#   'Right click broke after one week of use.',
#   0,
#   4),
#  (72,
#   '2018-04-11',
#   'This mouse is great.',
#   5,
#   1,
#   "I've had this mouse for like a week, and it's a joy to use. The mouse click is very pleasant, I love that you can turn the lights on the mouse on and off and the scroll wheel and side buttons are awesome! Plus it has DPI controls. If this mouse breaks for any reason, I want another one.",
#   0,
#   4),
#  (73,
#   '2018-04-10',
#   'Five Stars',
#   5,
#   1,
#   'Very responsive and easy to navigate blue lights are very cool',
#   0,
#   4),
#  (74, '2018-04-09', 'Five Stars', 5, 1, 'Love it', 0, 4),
#  (75,
#   '2018-04-09',
#   'Waste of money',
#   1,
#   1,
#   'The mouse scroll broke less than two weeks of using it. Waste of money.',
#   1,
#   4),
#  (76, '2018-04-09', 'Great ... low price, too', 5, 1, 'Works good', 0, 4),
#  (77,
#   '2018-04-09',
#   'Works fine so far',
#   5,
#   1,
#   "Works fine so far.  Plug-N-Play.  All functions are not described in the manual, but pretty east to figure out.  For the price it can't be beat.",
#   0,
#   4),
#  (78,
#   '2018-04-09',
#   'The perfect mouse for broke gamers',
#   5,
#   1,
#   'Cheap and affordable but  looks great and works perfectly (so far). I love how it only uses one battery.  multiple options  of the dpi and light.  extra customizable buttons on the side. very good!!!!',
#   0,
#   4),
#  (79,
#   '2018-04-08',
#   'Nice one but maybe a little bit small to me?',
#   4,
#   1,
#   'Really nice design, lightweight and easy to carry when going outside. Also It only using one single AA battery which make my life a lot easier..For me the biggest issue is that i cannot place my hand comfortably onto the mouse, only three of my fingers can rest on the mouse and two other hanging beside and make my hand feel awkward (maybe my hand too big or too long or both, there some photos comparison..) A little bit annoying there but still a great one to buy.',
#   0,
#   4),
#  (80, '2018-04-08', '👍', 5, 1, '👍', 0, 4),
#  (81,
#   '2018-04-06',
#   '... this for a few days and we are very happy with the high quality',
#   5,
#   1,
#   'We have been using this for a few days and we are very happy with the high quality. It came very quickly. Easy to set up. It saves batteries by turning off when not in use. Easy to turn it back on.  Highly responsive and easy to use. Very happy with this so far.',
#   0,
#   4),
#  (82,
#   '2018-04-06',
#   'Worked right away! Good product!',
#   5,
#   1,
#   'Works great! My son loves it!',
#   0,
#   4),
#  (83,
#   '2018-04-06',
#   'Five Stars',
#   5,
#   1,
#   'Very quiet and compact like the design and the price was perfect',
#   0,
#   4),
#  (84,
#   '2018-04-06',
#   'Smooth movement and quiet clicks.',
#   4,
#   1,
#   "Great mouse, a little small for my hand. Smooth movement and clicking. You can't hear the mouse when you right/left click. Though after about a month of use, you may begin to hear the muffled sound of a click, hover this isnt all that noticeable.",
#   0,
#   4),
#  (85,
#   '2018-04-06',
#   "and sometimes it seemed like i just don't feel the clicks",
#   5,
#   1,
#   "It might take some time for you to get used to silent click, initially, when i was using this mouse for the first time, it was so unusual to not hear the click sound, and sometimes it seemed like i just don't feel the clicks, but when i got used to it, it's a very nice mouse. Strongly recommend it.P.S. Now i can play games in office during work and not bother people with 3 clicks per second annoying sound lol",
#   0,
#   4),
#  (86,
#   '2018-04-05',
#   'Lacks consistency in connection/accuracy',
#   3,
#   1,
#   "I thought this mouse was worth a try due to how inexpensive it was.  I think it is overall a decent mouse with a good form factor that feels good in your hand.  It is fairly responsive, but accuracy is a bit off with the wireless.  Definitely not a mouse for gamers, as the accuracy and lack of consistency will result in many (virtual) deaths.  One feature of this mouse is that it is a silent mouse.  That means that when you click either button, you don't actually feel or hear the click.  I thought I would get used to this, but was not able to.Bottom line: If you are not a gamer and just looking for an inexpensive wireless mouse to navigate around web pages (but not MS Excel), then this mouse should work for you, assuming you are okay with not feeling or hearing the click of the mouse.",
#   0,
#   4),
#  (87,
#   '2018-04-05',
#   'Has a nice comfortable feel',
#   5,
#   1,
#   'Has a nice comfortable feel. Smooth and i like the look and so far response time has been pretty good.',
#   0,
#   4),
#  (88, '2018-04-05', 'Five Stars', 5, 1, 'Cant beat the price .', 0, 4),
#  (89,
#   '2018-04-04',
#   'I am pretty disappointed with the mouse',
#   1,
#   1,
#   "My left click is broken and I've only had it about a month, I don't use it a lot maybe three times a week for about 4 hours at a time playing games. I am pretty disappointed with the mouse. my return window has closed so I am not able to return it. Hope this does not happen to anyone else.",
#   1,
#   4),
#  (90,
#   '2018-04-03',
#   '5stars',
#   5,
#   1,
#   'Mouse works great, 5 stars, fast shipping too',
#   0,
#   4),
#  (91,
#   '2018-04-03',
#   'This mouse works well',
#   5,
#   1,
#   'Good mouse. works well, good price.',
#   0,
#   4),
#  (92,
#   '2018-04-02',
#   'Love it! The no sound click feature is great',
#   5,
#   1,
#   'Love it!  The no sound click feature is great!',
#   0,
#   4),
#  (93,
#   '2018-04-02',
#   'Decent mouse for general, non-gaming use.',
#   5,
#   1,
#   "I'm not a gamer so I can't speak to using this mouse for that purpose but as a general use mouse, it's great. Best thing about it is the clicking is almost silent. The light up option is really nice for me since I do a lot of work from home at night.",
#   0,
#   4),
#  (94, '2018-04-01', 'Five Stars', 5, 1, 'Very good', 0, 4),
#  (95, '2018-04-01', 'Five Stars', 5, 1, 'Works well, no problems.', 0, 4),
#  (96,
#   '2018-04-01',
#   'Amazing i recommend to anyone who needs a gaming mouse',
#   5,
#   1,
#   'This is an amazing mouse i love it it works so smoothly the leds work but i dont use them because the take to much charge plus i lt is silent no clicking',
#   0,
#   4),
#  (97, '2018-04-01', 'Five Stars', 5, 1, 'My son loves this mouse', 0, 4),
#  (98,
#   '2018-03-31',
#   'Five Stars',
#   5,
#   1,
#   'Great gamers device, looks cool, works well, very happy with the purchase, cheers',
#   0,
#   4),
#  (99,
#   '2018-03-31',
#   'Five Stars',
#   5,
#   1,
#   'Works as promised, mouse clicks are extremely quiet',
#   0,
#   4),
#  (100,
#   '2018-03-31',
#   'All promised was rewarded',
#   5,
#   1,
#   'It is truly silent',
#   0,
#   4),
#  (101,
#   '2018-03-30',
#   'Didn’t connect',
#   1,
#   1,
#   'Mouse wouldn’t connect via usb hub. Had a couple like this. Had to return.',
#   0,
#   4),
#  (102,
#   '2018-03-30',
#   'Best mouse you can buy.',
#   5,
#   1,
#   'Best mouse ever!!! BEST controls, cheap coolest ever.',
#   0,
#   4),
#  (103, '2018-03-30', 'Five Stars', 5, 1, '👊👊', 0, 4),
#  (104,
#   '2018-03-30',
#   'Easy to use.',
#   4,
#   1,
#   "It works well enough so far. No problems that I could see but it's still too early to tell.",
#   0,
#   4),
#  (105,
#   '2018-03-30',
#   'It broke all possible expectations when it came to my preconceived thoughts regarding a wireless mouse and am glad this was the brand to turn me to it',
#   5,
#   1,
#   "Didn't think it was wireless at first. Was surprised to find out it was. It broke all possible expectations when it came to my preconceived thoughts regarding a wireless mouse and am glad this was the brand to turn me to it.",
#   0,
#   4),
#  (106, '2018-03-29', 'Five Stars', 5, 1, 'love it', 0, 4),
#  (107,
#   '2018-03-29',
#   'Great price for a wireless mouse',
#   5,
#   1,
#   'Great price for a wireless mouse ! I got it for a gift and it is being used on a MacBook Pro . He is pleased and it works better than the touch pad forVideo Games and has a soft quiet click. I also got the extra warranty because it was under two dollars . Service was excellent . It arrived 2 days earlier than expected! Thank you !',
#   0,
#   4),
#  (108,
#   '2018-03-29',
#   'Five Stars',
#   5,
#   1,
#   'My 11 yr old is a gamer and he loves this mouse!',
#   0,
#   4),
#  (109,
#   '2018-03-29',
#   "This is the best mouse I've ever owned",
#   5,
#   1,
#   "This is the best mouse I've ever owned. So smooth, battery never dies. Also, the clicks are actually silent, which freaked me out at first. But I love it!!",
#   0,
#   4),
#  (110,
#   '2018-03-29',
#   'Five Stars',
#   5,
#   1,
#   'Love the silent click and looks.',
#   0,
#   4),
#  (111,
#   '2018-04-09',
#   'Bought again same model. Previous mouse was used for ...',
#   5,
#   1,
#   'Bought again same model. Previous mouse was used for 4 years until the left click button stops working properly so I could drag things around.',
#   0,
#   5),
#  (112,
#   '2018-03-31',
#   'Battery removal not easy, but nice, long-lasting product.',
#   4,
#   1,
#   "I like this product .It's light and easy to use without an annoying cord. And I never have to buy a new one as it works on batteries.The only thing is that the batteries are hard to remove and it came without instructions how to do it .  This is a flaw the manufacturer should address.  One can't really see how to get them out. I was afraid to break something if I forced  it and  went on-line and with the help there from other users I figured it out. I took almost 2 years before I needed new batteries, but I'm very diligent to shut off the battery function every time I stop using it.",
#   0,
#   5),
#  (113,
#   '2018-03-27',
#   'Four Stars',
#   4,
#   1,
#   'The scrolling wheel slips once in a while ..!',
#   0,
#   5),
#  (114,
#   '2018-03-21',
#   'works perfectly, however, in the meantime was able ...',
#   5,
#   1,
#   'works perfectly, however, in the meantime was able to fix my old mouse,  but still keeping this one for  future use.  Would purchase from this merchant again.',
#   0,
#   5),
#  (115,
#   '2018-03-19',
#   'Really good mouse',
#   5,
#   1,
#   "Was really glad to not have to make a trip to town to get a new mouse.  Functions perfectly except the roller squeaks....but isn't that what mice do?",
#   0,
#   5),
#  (116,
#   '2018-03-17',
#   'Excellent quality at a reasonable price',
#   5,
#   1,
#   'This has got to be one of our favorite new mice. Fast, precise, comfortable, and reasonably priced.',
#   0,
#   5),
#  (117,
#   '2018-03-15',
#   'Good Mouse',
#   5,
#   1,
#   'Good Mouse. Fits my needs well.',
#   0,
#   5),
#  (118, '2018-03-13', 'Five Stars', 5, 1, 'it is Great, I Love it', 0, 5),
#  (119, '2018-03-12', 'Five Stars', 5, 1, 'Love it', 0, 5),
#  (120,
#   '2018-03-08',
#   'look for a while for wireless mouse, this one ...',
#   5,
#   1,
#   'look for a while for wireless mouse, this one is exactly as I thought it would. works well on other surfaces.',
#   0,
#   5),
#  (121,
#   '2018-03-05',
#   'Five Stars',
#   5,
#   1,
#   'Love it, this is my first laser mouse ... much more accurate than optical ones. No complains.',
#   0,
#   5),
#  (122,
#   '2018-03-03',
#   'Five Stars',
#   5,
#   1,
#   'It feels perfect in my hand and so easy to use.',
#   0,
#   5),
#  (123,
#   '2018-03-01',
#   'Great mouse with a horrible wheel',
#   2,
#   1,
#   'Great mouse with a horrible wheel. If you are used to a very smooth wheel look elsewhere. This one is very primitive.',
#   0,
#   5),
#  (124,
#   '2018-02-28',
#   'Two Stars',
#   2,
#   1,
#   'The battery dont last two months.',
#   0,
#   5),
#  (125,
#   '2018-02-23',
#   'Lacks precision.',
#   2,
#   1,
#   'Feels uncomfortable. Lacks precision. At least for me.  Return was handled excellently!',
#   0,
#   5),
#  (126,
#   '2018-02-18',
#   "It's Great",
#   4,
#   1,
#   'Received on date promised well packaged. I plugged in the USB part and put in the batteries and that was it. I love the way it handles much more sensitive than the one I replaced.',
#   0,
#   5),
#  (127,
#   '2018-02-17',
#   'Very nice full-size mouse.',
#   5,
#   1,
#   "Very nice mouse.  Scroll wheel has several functions but perhaps not all are particularly useful.  Detents in wheel feel help with more precise scrolling.  Very good left and right button feel:  light but precise.  Excellent tracking on nearly any surface.  Mouse pads are sooo 90s.One quirk but not serious enough to delete a star:  A light push down on the scroll wheel switches from manual to auto scroll.  Sometimes this gets in the way but there seems no way to disable this feature on my computer (2017 Dell desktop).This is a wireless mouse, not a Bluetooth mouse.  In my experience, wireless mice (and other devices) connect nearly instantly with computer.  Bluetooth devices sometimes are hard to connect and may take some time to hook up.  In my opinion, Bluetooth is over rated;  wireless uses a different radio technology in the 2.4GHz band and is transparent to the user.In this case the mouse is ready to use as soon as you turn it on with the small switch on the underside.One difference:  HP appears to use infrared (like your TV remote) instead of visible light for mouse tracking.  You can't tell if the mouse is on or off by looking for a light. You have to check the switch position.  Not a disadvantage, just different.",
#   1,
#   5),
#  (128,
#   '2018-02-12',
#   "I don't remember changing batteries for it ever so in my opinion battery is pretty good. The design perfectly fits my hand grip ...",
#   5,
#   1,
#   "I have been using these for more over 2 years at my work. Even today it feels the same as it used to on day one. I don't remember changing batteries for it ever so in my opinion battery is pretty good. The design perfectly fits my hand grip and the base is quite smooth so it slides easily. No need to mention it's awesome wireless range. I bought it for 16$ and it is worth the price !",
#   0,
#   5),
#  (129, '2018-02-06', 'Two Stars', 1, 1, 'Wheel is not quiet/squeeks', 0, 5),
#  (130,
#   '2018-01-31',
#   'i definitely recommend this mouse',
#   5,
#   1,
#   'i definitely recommend this mouse, it works as it should, cheaper than dept stores, and arrives right to your door. batteries seem to last, ive used them for a month or two now, still going strong.',
#   0,
#   5),
#  (131,
#   '2018-01-30',
#   'Sad mouse, cursor jumps around and gets stuck',
#   2,
#   1,
#   "I'm very disappointed in this mouse. I tried it with 3 different computers, including a new HP, and it performed terribly with all three. I adjusted the mouse settings, but it didn't help. The cursor jumps around or gets stuck every time. I wonder if it has something to do with the Link-5 USB receiver. Several months ago, I bought an HP wireless keyboard that used Link-5 and it was incredibly frustrating because I had to hit the keys over and over again to type. This mouse reminds me of that experience. I returned the keyboard, and will probably return the mouse as well.",
#   0,
#   5),
#  (132,
#   '2018-01-30',
#   'Great choice.',
#   5,
#   1,
#   'Bought this to replace an old wireless mouse.  Very satisfied.',
#   0,
#   5),
#  (133,
#   '2018-01-29',
#   'One Star',
#   1,
#   1,
#   'This mouse works terribly, the cursor freezes and skips my cheap wired mouse works way better. very disappointed',
#   0,
#   5),
#  (134,
#   '2018-01-29',
#   'Helps my Tendinitis',
#   5,
#   1,
#   'I have tendinitis and this mouse works great for me.  I use this type of mouse at home and at work and have no pain throughout the day.',
#   0,
#   5),
#  (135, '2018-01-28', 'Five Stars', 5, 1, 'Good product.  No issues.', 0, 5),
#  (136,
#   '2018-01-25',
#   'Smooth mouse',
#   5,
#   1,
#   "Works great!! Smooth mouse no jumps or skips on screen, I don't have anything negative to say about it. I love it.",
#   0,
#   5),
#  (137,
#   '2018-01-25',
#   'Do the job.',
#   4,
#   1,
#   'Smooth, Big, Good reception.',
#   0,
#   5),
#  (138, '2018-01-25', 'Five Stars', 5, 1, 'Easy setup works great', 0, 5),
#  (139,
#   '2018-01-25',
#   'Three Stars',
#   3,
#   1,
#   'Technically not wireless. Still need toConnect a USB.',
#   0,
#   5),
#  (140,
#   '2018-01-22',
#   'Scroll wheel',
#   2,
#   1,
#   'The scroll wheel has developed dead spots resulting in erratic mouse movement.  I would like to disassemble and repair it, but that seems impossible to do without destroying it.',
#   0,
#   5),
#  (141,
#   '2018-01-18',
#   'Great mouse but interferes with desktop settings',
#   3,
#   1,
#   'The mouse itself is a great device and works very well. The problem is that it changes some of my settings on my HP desktop such as switching from dual monitor to single by changing my display configuration. If it continues, I will need to go back to the old mouse.',
#   1,
#   5),
#  (142,
#   '2018-01-18',
#   'Five Stars',
#   5,
#   1,
#   'Using it right now. Top Quality',
#   0,
#   5),
#  (143,
#   '2018-01-11',
#   'Love The Mouse!',
#   5,
#   1,
#   'This wireless mouse works and feels really well. Glad we bought it!',
#   0,
#   5),
#  (144,
#   '2018-01-11',
#   'Love it. I purchased this after my mini laptop ...',
#   5,
#   1,
#   "Love it. I purchased this after my mini laptop mouse got lost with the moving into a new place. But this works much better than the previous one and it's ergonomically comfortable to hold.",
#   0,
#   5),
#  (145, '2018-01-11', 'Accurate', 5, 1, 'Excellent for travel', 0, 5),
#  (146, '2018-01-10', 'Five Stars', 5, 1, 'Mouse works just fine', 0, 5),
#  (147,
#   '2018-01-08',
#   'For some reason it tends to freeze place for a ...',
#   4,
#   1,
#   "For some reason it tends to freeze place for a few seconds every so often.  May be my computer but don't know for sure.",
#   0,
#   5),
#  (148,
#   '2018-01-07',
#   'Five Stars',
#   5,
#   1,
#   'Its been working great! really light and sleek.',
#   0,
#   5),
#  (149,
#   '2018-01-05',
#   'Today and im really pleased with it',
#   5,
#   1,
#   'i,got my,HP Wireless Mouse X4000 With Laser Sensor, Today and im really pleased with it,its not much to get used too but its worth the money spent for it I,took it and un packed every thing that came with it and its been working perfectly since.',
#   0,
#   5),
#  (150,
#   '2018-01-05',
#   'Item as described, thank you!',
#   5,
#   1,
#   'Item as described, thank you!',
#   0,
#   5)]

# %% [markdown]
# Closing the database connection.

# %%
conn.close()
